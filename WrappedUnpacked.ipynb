# %%
#%% Imports
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import os
import pandas as pd
from datetime import datetime
import time

# %%
# Another way of authenticating using the Spotipy Library
def authenticate_spotify():
    """
    Uses environment variables to gain access to Spotify API
    
    Environment variables:
    SPOTIPY_CLIENT_ID
    SPOTIPY_CLIENT_SECRET
    SPOTIPY_REDIRECT_URI

    All found on the Spotify Developers Dashboard:
    https://developer.spotify.com/dashboard/20f128d8178c4ba3b89f4adf4e495b44/settings
    
    Returns:
        spotipy.Spotify instance that interacts with Spotify API
    """
    scope = ['playlist-read-private', 'user-read-recently-played', 'user-top-read', 'user-library-read']
    spotify = spotipy.Spotify(auth_manager=SpotifyOAuth(
        client_id=os.getenv('SPOTIPY_CLIENT_ID'),
        client_secret=os.getenv('SPOTIPY_CLIENT_SECRET'),
        redirect_uri=os.getenv('SPOTIPY_REDIRECT_URI'),
        scope=scope))
    
    return spotify

spotify = authenticate_spotify()
spotify

# %%
def get_users_top_tracks(spotify, time_range, offset=0):
    tracks = []
    top_tracks = spotify.current_user_top_tracks(limit=50, offset=offset, time_range=time_range)
    print('check')
    
    for item in top_tracks['items']:
        song_name = item['name']
        print(song_name)
        album_name = item['album']['name']
        release_date = item['album']['release_date']
        first_artist_id = item['artists'][0]['id']
        first_artist = spotify.artist(first_artist_id)
        first_artist_name = first_artist['name']
        artists = []
        for artist in item['artists']:
            artists.append(artist['name'])
        genres = first_artist['genres']
        length = item['duration_ms']
        popularity = item['popularity']
        explicit = item['explicit']
        
        

        tracks.append([song_name, artists, album_name, genres, length, popularity, release_date, explicit])
    return tracks

# %%
top_tracks = get_users_top_tracks(spotify, time_range='long_term')
top_tracks_df = pd.DataFrame(top_tracks, columns=['Title', 'Artists', 'Album', 'Genres', 'Length (ms)', 'Popularity', 'Release Date', 'Explicit'])
top_tracks_df.head()
# Out:
# check
# I'm In Here
# Einaudi: Experience
# Zimmer
# Taranta
# Ferma Zitella
# WECK MICH AUF
# enough for you
# Survive
# Tränen aus Kajal
# 26
# Kugeln im Lauf
# good 4 u
# Youth
# Another Love
# Where's My Love
# Levitating
# Veuve
# All For You
# Crime of Passion (Piano Solo Version) [From "Preston Tylk"]
# Stoned at the Nail Salon
# brutal
# Aufstehn! (feat. CeeLo Green)
# It's Ok
# jealousy, jealousy
# Una Mattina
# Ich glaub ich will heut nicht mehr gehen
# ONLY YOU (feat. Dhurata Dora)
# Choros
# Stamp On The Ground
# Flora
# Sleep When We're Dead - Video Edit
# Saved My Life
# Take Me To Church
# Half A Man
# I Can't Go on Without You
# Taranta
# Caribbean Queen (No More Love On the Run)
# Seven Days Walking / Day 1: The Path Of The Fossils
# Little Lighter
# Vergesse nie die Street
# Wonderful Life
# 17 für immer
# Nie verliebt
# Cello Suite No. 1 in G Major, BWV 1007: I. Prélude
# You Keep Me Hangin On
# Seven Days Walking / Day 1: The Path Of The Fossils
# Introductio Ad Regnum Tarantulae
# schwarze SUVs
# WECK MICH AUF - HELLMIX
# Cry (feat. Grimes)
#                  Title                                            Artists  \
# 0          I'm In Here                                              [Sia]
# 1  Einaudi: Experience  [Ludovico Einaudi, Daniel Hope, I Virtuosi Ita...
# 2               Zimmer                                          [Provinz]
# 3              Taranta  [Canzoniere Grecanico Salentino, Ludovico Eina...
# 4        Ferma Zitella                    [Traditional, Ludovico Einaudi]
#
#                               Album  \
# 0                       We Are Born
# 1  In A Time Lapse (Deluxe Edition)
# 2        Zu spät um umzudrehen - EP
# 3                          Quaranta
# 4                   Taranta Project
#
#                                               Genres  Length (ms)  Popularity  \
# 0            [australian dance, australian pop, pop]       221320          50
# 1             [compositional ambient, neo-classical]       315426          55
# 2                    [german indie folk, german pop]       177818          57
# 3          [italian folk, musica etnica, tarantella]       187146          29
# 4  [gregorian chant, hengelliset laulut, puirt-a-...       245987          29
#
#   Release Date  Explicit
# 0   2010-06-18     False
# 1   2013-01-01     False
# 2   2021-06-11     False
# 3   2015-04-14     False
# 4   2015-04-21     False

# %%
top_tracks_df.to_csv('top_tracks_long_term.csv', encoding='utf-8-sig')

# %%
def convert_datetime_string_to_milliseconds(datetime_str):
    """
    Converts a datetime string in the format '%Y-%m-%dT%H:%M:%S.%fZ' to milliseconds.

    Args:
        datetime_str (str): The datetime string to convert.

    Returns:
        int: The datetime converted to milliseconds.
    """
    datetime_obj = datetime.strptime(datetime_str, '%Y-%m-%dT%H:%M:%S.%fZ')
    milliseconds = int(time.mktime(datetime_obj.timetuple()) * 1000)
    return milliseconds

def fetch_last_function_call():
    with open('recently_played_songs.csv', 'r', errors='ignore') as csvfile:
        last_row = csvfile.readlines()[-1]
        
    date_time_string = last_row.split(',')[-1].replace('\n', '')
    last_function_call_ms = convert_datetime_string_to_milliseconds(date_time_string)
    return last_function_call_ms, date_time_string

# %%
with open('recently_played_songs.csv', 'r', errors='ignore') as csvfile:
        last_row = csvfile.readlines()[-1]
print(last_row)
date_time_string = last_row.split(',')[-1].replace('\n', '')
date_time_string
# Out:
# Mann vom Fach,Levin Liam,Mann vom Fach,[],160813,64,2023-10-06,playlist,False,2023-12-13T11:21:25.234Z
# '2023-12-13T11:21:25.234Z'

# %%
after, date_time_string = fetch_last_function_call()
date_time_string
# Out:
# '2023-12-13T11:13:03.990Z'

# %%
def get_recently_played_songs(spotify):
    tracks = []
    after, date_time_string = fetch_last_function_call()
    recently_played_songs = spotify.current_user_recently_played(limit=50, after=after)
    # print('check')
        
    for item in recently_played_songs['items']:
        song_name = item['track']['name']
        print(song_name)
        played_at = item['played_at'] 
        if played_at == date_time_string:
            print('    Reached last song of previous call. Stopping here...')
            break
        album_name = item['track']['album']['name']
        release_date = item['track']['album']['release_date']
        first_artist_id = item['track']['artists'][0]['id']
        first_artist = spotify.artist(first_artist_id)
        first_artist_name = first_artist['name']
        artists = []
        for artist in item['track']['artists']:
            artists.append(artist['name'])
        genres = first_artist['genres']
        length = item['track']['duration_ms']
        popularity = item['track']['popularity']
        try:
            context = item['context']['type']
        except TypeError:
            context = 'saved'
        explicit = item['track']['explicit']

        tracks.append([song_name, artists, album_name, genres, length, popularity, release_date, context, explicit, played_at])

    return tracks

# %%
recently_played_songs = get_recently_played_songs(spotify)
# Out:
# Death by a Thousand Cuts
# Death by a Thousand Cuts
# Empty
# schwarze SUVs
# Schmetterling
# Hör mal mein Herz <3…
# Du hast mich nie geliebt </3…
# Fake As Hell (with Avril Lavigne)
# Fake As Hell (with Avril Lavigne)
# deep fake
# Psycho
# Psycho
# DArkSide
# Heartbreak Feels So Good
# War
# Lost Without You
# Venom
# Fantasy
# Reckless & Relentless - Document One Remix
# Fuck (feat. Josh Franceschi)
# Bite My Tongue
# Chicken Bone
# Another You
# Vice Grip
# High For This - Original
# Ich hass dich
# DER LETZTE SONG (ALLES WIRD GUT) (feat. Nina Chuba)
# Pray For Me
# Insomnia (feat. Giant Rooks)
# Playing God
# Stature
# Stature
# Nie verliebt
# Singing Low
# XO
# Muévelo
#     Reached last song of previous call. Stopping here...

# %%
recently_played_songs_df = pd.DataFrame(recently_played_songs, columns=['Title', 'Artists', 'Album', 'Genre', 'Length (ms)', 'Popularity', 'Release Date', 'Context', 'Explicit', 'Played at'])
recently_played_songs_df.sort_values('Played at', axis=0, ascending=True, inplace=True)
recently_played_songs_df.head()
# Out:
#            Title               Artists  \
# 34            XO                [EDEN]
# 33   Singing Low            [The Fray]
# 32  Nie verliebt      [Paula Hartmann]
# 31       Stature  [Drama B, Besomorph]
# 30       Stature  [Drama B, Besomorph]
#
#                                       Album  \
# 34         i think you think too much of me
# 33  Through the Years: The Best of The Fray
# 32                             Nie verliebt
# 31                                  Stature
# 30                                  Stature
#
#                                       Genre  Length (ms)  Popularity  \
# 34                        [indie poptimism]       159512          66
# 33  [neo mellow, piano rock, pop, pop rock]       263724          32
# 32                                       []       212661          59
# 31      [deep underground hip hop, traprun]       182697          34
# 30      [deep underground hip hop, traprun]       182697          34
#
#    Release Date Context  Explicit                 Played at
# 34   2016-08-19   saved     False  2023-12-13T17:55:12.377Z
# 33   2016-11-04   saved     False  2023-12-13T17:59:23.234Z
# 32   2022-08-26   saved     False  2023-12-13T23:48:20.463Z
# 31   2018-11-23   saved     False  2023-12-13T23:48:30.336Z
# 30   2018-11-23   saved     False  2023-12-14T11:46:35.379Z

# %%
recently_played_songs_df.to_csv('recently_played_songs.csv', mode='a', encoding='utf-8-sig', header=False, index=False)

# %%
def get_users_saved_tracks(spotify, offset):
    tracks = []
    saved_songs = spotify.current_user_saved_tracks(limit=50, offset=offset)
    print('check! Offset =', offset)
        
    for item in saved_songs['items']:
        song_name = item['track']['name']
        print(song_name)
        album_name = item['track']['album']['name']
        first_artist_id = item['track']['artists'][0]['id']
        first_artist = spotify.artist(first_artist_id)
        first_artist_name = first_artist['name']
        artists = []
        for artist in item['track']['artists']:
            artists.append(artist['name'])
        genres = first_artist['genres']
        length = item['track']['duration_ms']
        popularity = item['track']['popularity']
        added_at = item['added_at']
        release_date = item['track']['album']['release_date']
        explicit = item['track']['explicit']
        

        tracks.append([song_name, artists, album_name, genres, length, popularity, release_date, added_at, explicit])

            
    return tracks

# %%
max_number_of_tracks = 3000
all_saved_tracks = []
offset = 0
while offset < max_number_of_tracks:
    saved_tracks = get_users_saved_tracks(spotify, offset=offset)
    all_saved_tracks += saved_tracks
    offset += 50
# Out:
# check! Offset = 0
# Empty
# Fake As Hell (with Avril Lavigne)
# love is embarrassing
# L’enfer
# Santé
# Formidable
# Tous les mêmes
# Give It Up to Me
# G.O.A.T.
# Playing God
# Seeing Red
# Gekreuzte Finger
# Cry (feat. Grimes)
# Miss Nectarine
# Warum lügst du?
# Forever & Ever More
# Save Yourself
# Break My Fall
# Happier Than Ever
# Honey
# To Me It Was
# Is There Something in the Movies?
# Big Wheel
# Death by a Thousand Cuts
# Lost
# Mirrors - Hypertechno Remix
# Babyblau - Remix
# Typa Girl
# Herzcrash
# Schmetterling
# Hör mal mein Herz <3…
# Ohne Benzin
# KETA UND KRAWALL
# Maldosa
# MALDITA PERIGOSA
# Maldita
# MANO DO AK
# Let's Go!
# Devils Price
# Halloweenie V: The Moss King
# R U Mine?
# Paint
# Energies
# Rehab
# Machines
# DArkSide
# PARANOID
# Vois sur ton chemin - Techno Mix
# Dead Inside
# Nie verliebt
# check! Offset = 50
# Beautiful Escape
# Superstar (feat. Remington Leith)
# Kugeln im Lauf
# Veuve
# schwarze SUVs
# Danke Nein
# Wenn Du weinst
# De Selby (Part 2)
# Kein Happy End
# Eat Your Young
# Put It on Me
# Tauchen
# I Can't Go on Without You
# To Be Alone
# Gramm für Gramm
# Levitating
# Pretty Please
# Hymn for the Weekend
# Con Miedo a Ti
# Moonlight Magic
# You Oughta Know
# No Me Salves
# De la Cueva a los Olivos
# Youth
# Heaven Shall Burn
# Daisy
# Anything But
# All Things End
# De Selby (Part 1)
# Roses
# My Best Self
# Bad Blood
# Such Small Hands
# Safer in the Forest/Love Song for Poor Michigan
# Unholy Confessions
# Unholy (feat. Kim Petras)
# In The Silence
# Lost In The Rhythm
# Papaoutai
# Come Dancing
# bad idea right?
# Goon Squad
# Humble
# Too Close
# Avril
# Baby, You Wouldn't Last A Minute On The Creek
# Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)
# Skinny Love
# Family Line
# Drowned in Emotion
# check! Offset = 100
# Criminal
# Good Riddance (feat. Ashley Barrett)
# All My Best Friends Are Metalheads
# War of Change - 2023
# Might Love Myself
# mietfrei
# WECK MICH AUF - HELLMIX
# ANIMAL
# 2L8 UNDEAD
# Moth to a Flame
# Temptation
# Welcome to the DCC
# Members Only
# vampire
# DYWTYLM
# Pon de Replay
# Schwarz zu blau
# Kopf verloren
# Glatteis
# Blaues Licht
# Backbone
# All the Pretty Girls
# Friesenjung
# Hurt
# Keeping You Around
# Ein Auge blau
# Nate Growing Up
# Back To You
# THE GUILTY PARTY
# Lost in a Wave
# Sugar, We're Goin Down
# The Science of Selling Yourself Short
# L8r Boi
# Slumber Party (feat. Princess Nokia)
# Are You Ready
# Red Light Kisser (with Jordan Pundik of New Found Glory)
# Electric Love
# Welcome Home
# Wish You Were Here
# Stairway to Heaven - 1990 Remaster
# Heartbeats
# "The Take Over, The Breaks Over"
# WARUM LÜGST DU MICH AN
# Mach kaputt
# Ich hass dich
# Bedroom Exile
# enough for you
# deja vu
# Popular Monster
# Bei Dir
# check! Offset = 150
# Dark Void
# Chalk Outlines
# Locksmith
# I Know
# traitor
# Mamma la rondinella
# Big Body Benz
# Oh Jonny
# 200 km/h
# Augenbling
# Kein Problem
# Zucker (feat. Vanessa Mason)
# Ey DJ
# Roses
# Kleine Hure
# Liebe zu dritt
# Let's Get It Started
# Schüttel deinen Speck
# Diego Maradona
# Beef
# Willst du
# Freaky Like Me
# Standard (feat. Trettmann, Gringo, Ufo361 & Gzuz)
# Roller
# Zimmer
# Ausgehen
# Beggin'
# Watermelon Sugar
# Stamp On The Ground
# Everywhere I Go
# Doch in der Nacht
# Aufstehn! (feat. CeeLo Green)
# Der letzte Tag
# Teenage Dirtbag
# Leb deinen Traum (Digimon)
# Du hast den schönsten Arsch der Welt
# Dancing in the Moonlight
# Wir werden siegen (Digimon)
# Purple Lamborghini (with Rick Ross)
# Ding
# Kiwi
# Danza Kuduro
# check! Offset = 650
# Sleeping Inside
# After Tonight
# Save Him
# Golden Train
# Criminal
# Caribbean Queen (No More Love On the Run)
# Taximann
# again&again
# AMNEZIA 2
# Daniel Lee
# Loco Contigo (feat. J. Balvin & Tyga)
# Junto Al Amanecer
# Mensch
# BLESSED (feat. Capital Bra)
# Strobo Pop
# Almost Lover
# Mask Off (feat. Kendrick Lamar) - Remix
# Forever
# Sucker
# Flugangst
# Pogo
# Afterhour
# Ich will dich wiedersehen
# Sacrificial
# ONLY YOU (feat. Dhurata Dora)
# YaYaYa
# Dark Side
# Rapstar
# EL PONY
# Summerbreeze
# L.O.V.E.
# Man Must Dance
# Unterfickt und geistig behindert
# FEUER
# ALL OF MY DREAMS
# GITARRE
# DU TUST MIR NICHT GUT
# ALLES HELAL
# NUR MIR
# SCHWARZ
# LIPPENSTIFT
# FEIND (feat. AZAD)
# KANN DAS BITTE SO BLEIBEN
# ABER WO BIST DU
# AUGEN ZU (feat. Samra)
# OHNE LIEBE
# FREUNDE
# ALASKA
# EIN LETZTES MAL
# Moonlight Sonata (1st Movement)
# check! Offset = 700
# Lauf davon
# Decode - Acoustic Version
# Circles (based on Ludovico Einaudi "Experience")
# You Found Me
# Who You Are
# This Is Home
# Two Men In Love
# How to Save a Life
# Mind over Matter (Acoustic)
# Sweater Weather
# Hello
# Taranta - Remastered 2020
# Einaudi: Experience
# Fumes
# Saved My Life
# Three Cheers For Five Years
# XO
# I'm In Here
# Wonderful Life
# Cut My Hair
# Awaken
# Glass House (feat. Naomi Wild)
# This Is A Call
# Blood Knows
# She Couldn't
# Tommi - Live
# Una Mattina
# Saudades
# drowning.
# Meine Soldaten
# The Scientist
# Dust in the Wind
# Let It Go
# No Time To Die
# LOST IN THE ECHO - Acapella
# Snuff
# Feeling Good
# Ferma Zitella
# Ice Box
# JUST LIKE YOU
# Das ist alles von der Kunstfreiheit gedeckt
# Laisse tomber (feat. Dr. Beriz & Insolent)
# Malheur, malheur
# Iodine
# Off With Her Head
# Up In Flames
# Theatre
# Make A Move
# Interlude
# Oulala
# check! Offset = 750
# Dinner & Diatribes
# High For This
# Right Here
# Friends
# Moment's Silence (Common Tongue)
# Call Out My Name
# Angel of Small Death and the Codeine Scene
# Stresserblick
# Musterschwiegersohn
# BADT
# Whine & Kotch - Raw
# The Vibe
# Let Me Go
# Here Without You
# When I'm Gone
# Kryptonite
# It's Not My Time
# The Real Life
# DFA
# Forrest
# 700 Main Street
# UFO
# check! Offset = 900
# i don't know what to say
# MANTRA
# wonderful life (feat. Dani Filth)
# nihilist blues (feat. Grimes)
# ouch
# fresh bruises
# why you gotta kick me when i'm down?
# sugar honey ice & tea
# medicine
# i apologise if you feel something
# in the dark
# mother tongue
# heavy metal (feat. Rahzel)
# Dear Lord
# Gospel
# Bossmove
# Donlife (feat. Camron)
# Monument (Outro)
# Usain Bolt (Hoodtape 3)
# Prison Break (Hoodtape 3)
# Blow Out
# Da
# Das erste Mal (feat. 18 Karat)
# Arm aus dem Fenster (Hoodtape 3)
# Nightking (Hoodtape 3 Intro)
# Frontale Faust (Hoodtape 3)
# Empire State of Grind (Hoodtape 3)
# Cohiba Symphony
# Makiaveli
# Most Wanted (Hoodtape 3)
# Löwe
# Psycho (feat. Farid Bang)
# Der weiße Lotus (Hoodtape 3)
# MTV Cribs (Hoodtape 3)
# Push it to the Limit (Hoodtape 3)
# Did It First
# All Night Long
# No Respect
# No Cappin
# Why is You Leavin
# Crackin On My Own
# Shape Up
# One Little String
# You Can't Mess It Up
# Chemical Machine
# Scarlet Letter
# 1896
# Die Trying
# Friendly Enemies
# Light the Night
# check! Offset = 950
# 10,000 Hours
# Lifeline
# Can't Help
# Running
# Show Me
# Something Good
# Bad Company
# Porch Swing
# Cruel Life
# Waiting
# No More
# Stronger on Your Own
# Already Gone
# The Best Ones Lie
# Saviour of Nothing
# In Another Time
# Are You Ready
# Watch You Burn
# A Reason to Fight
# Hold on to Memories
# Nummer unterdrückt
# Krimineller
# Alien
# Von ihnen gelernt
# Kokain
# Risiko
# Prominent
# 500 PS
# Ja Mann!
# 100
# Nein
# Kompanie
# Intro
# I O U
# Back Again
# Straight to My Head
# Danger
# Miracle in the Mourning
# 3AM
# Losing You
# Fast Forward
# Predictable
# Pray For Me
# Kommissar
# Eismann
# Interstellar
# Kids
# Believe
# Intro
# No Pressure
# check! Offset = 1000
# Initials for Gainsbourg
# Swing Low
# Pamela
# Weight of the World
# Fractured and Dazed
# Picture Frame
# Chicken Bone
# All the Time
# Honey Bee
# Four Leaf Clover
# Suchtfaktor
# Schon wieder Sonntag
# Unbekannter Titel
# Schwarzer Afghane
# Einbürgerungstest für schwererziehbare Migrantenkinder
# Cockpit - Bonus Track
# Du hast noch nicht mal Kekse Zuhause
# Der Kanalreiniger
# 53119
# Big King XXL
# Ein tiefsinniges, sozialkritisches und moralvermittelndes Lied
# Karnevalsverein - Bonus Track
# Nuttööö
# Das Wasser ist nass
# Illegal, Legal, Egal...
# Bonn 17
# Rocco Siffredi
# Harz 4
# Mitternacht 2
# Sturmmaske auf - Gold war Gestern RMX
# All Eyez on Us
# Vanderlei Silva
# Geister, die du riefst
# Boss und Banger
# In die Unendlichkeit
# Der letzte Krieg
# Tetris mit Batzen Scheinen
# Bis es bricht
# Parabel
# Die Guten von uns
# Atempause
# Aus verbrannter Erde
# Signal
# Winterschlaf
# Agora
# Chrom
# Wenn der Wind sich dreht
# Buzz
# Vicious
# Painkiller
# check! Offset = 1050
# Conflicted
# Black Vultures
# Killing Ourselves to Live
# Skulls
# White Dress
# Heart of Novocaine
# Do Not Disturb
# Uncomfortable
# The Silence
# Blutdiamanten
# Angeberprollrap Infinity (Outro)
# Wall Street
# Nebel
# Mörder
# Hoodtales IV
# Kalter Krieg
# Kool & the Gang
# Intro
# John Gotti
# Genozid - Bonus Track
# Winter
# Over It
# Don't Need You
# Under Again
# The Very Last Time
# Coma
# Piece Of Me
# Leap Of Faith
# Breathe Underwater
# Gravity
# Letting You Go
# Not Dead Yet
# Criminal
# Dead and Gone
# Sidelines
# Crystal Ball
# The Fix Up
# Our Time to Go
# Lightning
# Time Machine
# Mine is Gold
# Something About You
# Frozen
# Cut Through the Static
# Safe Haven
# Glass Hearts
# Identity Disorder
# Would You Still Be There
# Break Free
# Feels Like Forever - Acoustic
# check! Offset = 1100
# Public Service Announcement
# Broken Generation
# You're Not Alone
# You Make Me Sick
# Bones Exposed
# Space Enough To Grow
# Something To Hide
# Never Giving Up
# Another You
# Wieso Weshalb Warum
# Mehr Tilidin
# 100 Bars/Wake-Up Call
# Auf der Jagd
# One Point Perspective
# American Sports
# Tranquility Base Hotel & Casino
# The Ultracheese
# Four Out Of Five
# The World's First Ever Monster Truck Front Flip
# She Looks Like Fun
# Science Fiction
# Batphone
# Ohne mein Team
# Killa
# Erblindet
# Daneben
# Attackieren
# Evil
# Dankbarkeit
# Vaporizer
# Intro
# Skimaske
# Mörder
# Palmen aus Plastik
# Ruhe nach dem Sturm
# Ciao Ciao
# Close Your Eyes
# Down
# Save Yourself
# Lyra
# Torn in Two
# Vega
# Tourniquet
# Red Cold River
# The Dark of You
# Blood
# Psycho
# Feed the Wolf
# Dangerous
# Oblivion
# check! Offset = 1150
# State of My Head
# Thick as Thieves
# How Did You Love
# Outcast
# Asking for It
# Cut the Cord
# It All Adds Up
# Black Cadillac
# Misfits
# If You Only Knew
# Cyanide Sweet Tooth Suicide
# Call Me
# Breaking Inside (feat. Lzzy Hale of Halestorm)
# What a Shame
# The Crow & the Butterfly
# Diamond Eyes (Boom-Lay Boom-Lay Boom)
# Devour
# Cry for Help
# Her Name Is Alice
# I Own You
# The Energy
# Sound of Madness
# Second Chance
# Sin with a Grin
# Junkies for Fame
# Son of Sam
# Love Is Madness (feat. Halsey)
# One Track Mind (feat. A$AP Rocky)
# Rider
# Great Wide Open
# Rescue Me
# Remedy
# Hail To The Victor
# Walk On Water
# Monolith
# Dangerous Night
# Dept. of False Hope
# Corners
# Over My Head (Cable Car)
# Singing Low
# Love Don't Die
# Heartbeat
# All At Once
# Look After You
# Never Say Never
# Heartless
# A Single Moment Of Sincerity - KC Blitz Remix
# A Candlelit Dinner With Inamorta - Run DMT Remix
# If You Can't Ride Two Horses At Once...You Should Get Out Of The Circus - Noah D Remix
# Final Episode (Let's Change The Channel) - Borgore Remix
# check! Offset = 1200
# Reckless And Relentless - Document One Remix
# Everywhere I Go - Live
# California - Live
# Sell Your Soul - Live
# Black Dahlia - Live
# Tear It Up
# El Urgencia
# Shout At The Devil
# Immigrant Song
# Dove And Grenade
# No. 5 - Live
# Contagious
# Transfigured
# Relentless
# -
# Like a Ghost
# Game of War
# The Lie
# Pain
# +
# Away
# Down the Road
# Real
# The Hunger
# Molly (feat. Brendon Urie of Panic at the Disco)
# Lemme Freak
# Professional Rapper (feat. Snoop Dogg)
# Banshee
# The Scene (feat. Fronzilla)
# New Age
# Shallows
# Nightlife (feat. Little Big)
# Calling
# check! Offset = 1550
# VIP
# The Devil Within
# Back in the Bizz
# Rooftop
# The Devil Within (feat. Tobias Rauscher) - Acoustic
# MC Thunder
# 'Til Death Do Us Part
# Mask (Radio Edit)
# Ultraviolence
# Skin Deep
# Things That Make You Scream
# The Core
# Intersections
# Truth in Lies
# Mask
# Break Away
# Reach
# Darkest Hour
# Pieces
# Pizza zum Frühstück
# Pinky & Brain
# Rotlichtlampe
# Twelve Inch Skit
# Galapresse
# Ohne Mo's nix los
# Flugblätter
# Verfolgungswahn
# Victory
# Unerreichbar
# Astronautenkapsel
# Sifu
# Unsere Stadt
# Dopamin
# Zoo Pauli
# Irgendwo
# Lampenfieber
# Schall und Rauch
# Bahnhaltestelle
# Eis am Stiel
# Ich und die Musik
# Alibier
# Zum goldenen Brausefass
# Nordseite
# Ouroboros
# Dankeschön
# Gehheimtipp
# Tinderrail
# Undercover Blues
# Supersoaker
# Jukebox
# check! Offset = 1600
# Intercity
# Beats Rhymes & Sprays
# Imperfekt
# Status Zwo
# Boardmeeting
# Throw It On Me
# Apologize
# Oh Timbaland
# One and Only
# Miscommunication
# Come and Get Me
# The Way I Are
# Fantasy
# Bounce
# 2 Man Show
# Scream
# Release
# Kill Yourself
# Hello
# Bombay
# Time
# Give It To Me
# My December
# Pushing Me Away
# One Step Closer
# Cure for the Itch
# Papercut - Live at BBC1
# Points of Authority
# A Place for My Head
# With You
# In the End
# By Myself
# Runaway
# High Voltage
# Forgotten
# Je te pardonne (feat. Sia) - Pilule bleue
# Mayweather (feat. Djuna Family) - Pilule rouge
# La main du roi - Pilule rouge
# 150 - Pilule violette
# Cadeaux - Pilule bleue
# Number One (feat. H Magnum) - Pilule bleue
# ABCD - Pilule rouge
# Hasta Luego - Pilule bleue
# Loin (feat. Dany Synthé & soFLY & Nius) - Pilule violette
# Boucan (feat. Jul & DJ Last One) - Pilule violette
# Sapés comme jamais (feat. Niska) - Pilule bleue
# Pense à moi - Pilule violette
# Tout donner - Pilule violette
# Laissez passer - Pilule bleue
# Longue vie (feat. Lefa) - Pilule rouge
# check! Offset = 1650
# Paname - Pilule violette
# Tu vas me manquer - Pilule bleue
# Brisé - Pilule bleue
# Est-ce que tu m'aimes ? - Pilule bleue
# Ma beauté - Pilule violette
# Hamma! - Single Edit
# Partybus
# No Es Igual
# Chica
# General
# Schöne neue Welt - Single Version
# Siento
# Somma im Kiez
# Ey DJ - Single Edit
# Berlin City Girl
# Steh auf
# Move It
# Vitamina
# Eiskalt
# Monsta
# Life @ 11
# Welcome to the Family
# Homesick
# I'm Made of Wax, Larry, What Are You Made Of?
# Holdin' It Down for the Underground
# Have Faith In Me
# My Life for Hire
# You Already Know What You Are
# The Downfall of Us All
# NJ Legion Iced Tea
# Mr. Highway's Thinking About the End
# Another Song About the Weekend
# Paranoia
# Don't Threaten Me with a Good Time
# crushcrushcrush
# Pop Punk Kid
# If It Means a Lot to You
# Right Back At It Again
# Forever and Never
# Ready for Repair (Captain Midnite Remix feat. Jonny Craig, Kyle Lucas)
# Sleep Well, Darling
# The Architect (Part 2)
# The Wild
# How We Survive
# Ready For Repair
# Maybe Next May
# Artist vs. Who?
# Infinite Escape
# Heartbreak Kids
# Fragile Figures
# Live Together, Die Alone
# Sometimes You're The Hammer, Sometimes You're The Nail
# Dance Of The Dead
# Brand New Day
# Worthless
# Monster - Transformers Soundtrack Version
# I'm Just A Kid
# Avalanche
# Dear Youth (Day 52)
# Fallin'
# Basket Case
# I Don’t Want To Be Here Anymore
# Mr. Brightside
# I Knew You Were Trouble
# Hand Of Blood
# Your Betrayal
# Parallels
# Last Resort
# check! Offset = 2050
# Is Anyone Up
# Your Love Is a Lie
# Jet Lag (feat. Marie-Mai)
# Going Under
# Runaway
# Into You
# Falling Apart
# One For the Money
# This War Is Ours (The Guillotine II)
# Perfect - Acoustic Version
# Seven Hills (feat. Jenny Staniforth) - Alternate version
# Faded
# Grand Theft Autumn / Where Is Your Boy
# Untitled (How Could This Happen to Me?)
# Break Stuff
# Flavor Of The Weak
# My Demons
# Rise
# Inside
# Misery Business
# Shut Up!
# Gives You Hell
# Irresistible
# Hero
# Monster
# Rise

# %%
len(all_saved_tracks)
# Out:
# 2076

# %%
all_saved_tracks_df = pd.DataFrame(all_saved_tracks, columns=['Title', 'Artists', 'Album', 'Genre', 'Length (ms)', 'Popularity', 'Release Date', 'Added at', 'Explicit'])
all_saved_tracks_df.head()
# Out:
#                                Title                        Artists  \
# 0                              Empty                     [Letdown.]
# 1  Fake As Hell (with Avril Lavigne)  [All Time Low, Avril Lavigne]
# 2               love is embarrassing               [Olivia Rodrigo]
# 3                            L’enfer                      [Stromae]
# 4                              Santé                      [Stromae]
#
#                                Album  \
# 0               Crying In The Shower
# 1  Fake As Hell (with Avril Lavigne)
# 2                               GUTS
# 3                          Multitude
# 4                          Multitude
#
#                                              Genre  Length (ms)  Popularity  \
# 0                                               []       213268          59
# 1  [modern rock, neon pop punk, pop emo, pop punk]       179166          68
# 2                                            [pop]       154516          82
# 3                           [belgian pop, g-house]       189720          54
# 4                           [belgian pop, g-house]       191000          55
#
#   Release Date              Added at  Explicit
# 0   2023-02-24  2023-12-15T09:17:18Z     False
# 1   2023-09-15  2023-12-14T22:37:06Z      True
# 2   2023-09-08  2023-12-11T22:39:25Z      True
# 3   2022-07-27  2023-12-10T12:46:33Z     False
# 4   2022-07-27  2023-12-10T12:46:28Z     False

# %%
all_saved_tracks_df.shape
# Out:
# (2076, 9)

# %%
all_saved_tracks_df.to_csv('saved_tracks_15_12_2023.csv', encoding='utf-8-sig')
